# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from keras.layers import Convolution2D, MaxPooling2D, Activation
from keras.models import Sequential

# %%
import cv2

# %%
cat = cv2.imread("cat.png")

# %%
plt.imshow(cat)

# %%
cat.shape
# Out:
# (320, 400, 3)

# %%
model = Sequential()
model.add(Convolution2D(3, (3, 3), input_shape = cat.shape))

# %%
cat_batch = np.expand_dims(cat, axis = 0)

# %%
conv_cat = model.predict(cat_batch)

# %%
def visualize_cat(model, cat):
    cat_batch = np.expand_dims(cat, axis = 0)
    conv_cat = model.predict(cat_batch)
    conv_cat = np.squeeze(conv_cat, axis = 0)
    print(conv_cat.shape)
    plt.imshow(conv_cat)

# %%
visualize_cat(model, cat)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (318, 398, 3)

# %%
model = Sequential()

# %%
model.add(Convolution2D(3, (20, 20), input_shape = cat.shape))

# %%
visualize_cat(model, cat)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (301, 381, 3)

# %%
def print_the_cat_nice_way(model, cat):
    cat_batch = np.expand_dims(cat, axis = 0)
    conv_cat2 = model.predict(cat_batch)
    conv_cat2 = np.squeeze(conv_cat2, axis=0)
    print(conv_cat2.shape)
    conv_cat2 = conv_cat2.reshape(conv_cat2.shape[:3])
    print(conv_cat2.shape)
    plt.imshow(conv_cat2)

# %%
print_the_cat_nice_way(model, cat)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (301, 381, 3)
# (301, 381, 3)
